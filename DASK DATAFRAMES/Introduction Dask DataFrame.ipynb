# %%
import dask.dataframe as df

# %%
dummy_df = df.read_csv('*[1-2].csv',sep='|')

# %%
dummy_df.visualize()

# %%
len(dummy_df)
# Out:
# 1000000

# %%
dummy_df= dummy_df[dummy_df.Budget.notnull()]

# %%
dummy_df.RuntimeMinutes.max().visualize()

# %%
dummy_df.head()
# Out:
#    Unnamed: 0   ID_x  Budget  StudioInterference  PrePremiereScreenings  \
# 0           0  56132     NaN                 NaN                    NaN
# 1           1  68488     NaN                 NaN                    NaN
# 2           2  48663     NaN                 NaN                    NaN
# 3           3  51585     NaN                 NaN                    NaN
# 4           4  48180     NaN                 NaN                    NaN
#
#    HeavyMarketing  RuntimeMinutes                        Title     IDImdb  \
# 0             NaN              94  Winnetou: The Red Gentleman  tt0058751
# 1             NaN             100                 The Last Day  tt0073267
# 2             NaN              75             Fury at Showdown  tt0050420
# 3             NaN              73             Comanche Station  tt0053729
# 4             NaN              93        Tension at Table Rock  tt0049834
#
#   ReleaseDate  ... IDAwardType Category IDMovie_y  IDMovie  IDMoviePortal  \
# ...

# %%
dummy_df.drop(['ID'],axis=1).visualize()

# %%
dimmy_df_group_minutes = dummy_df.groupby('Title')['RuntimeMinutes'].max()

# %%
dimmy_df_group_minutes.compute()
# Out:
# Title
# $1,000 on the Black                      102
# '49-'17                                   61
# 'Doc'                                     96
# 'Neath the Arizona Skies                  52
# .hack//G.U. Trilogy                       93
#                                         ...
# Ponies                                    73
# Redlegs                                   67
# The Death and Life of John F. Donovan    127
# Golda's Balcony                           95
# Silver Circle                             90
# Name: RuntimeMinutes, Length: 57028, dtype: int64

# %%
dummy_df.nlargest(20,'RuntimeMinutes').head()
# Out:
#        Unnamed: 0    ID_x  Budget  StudioInterference  PrePremiereScreenings  \
# 21490      125301  214296     NaN                 NaN                    NaN
# 29157      229157  214296     NaN                 NaN                    NaN
# 12724       82918   68664     NaN                 NaN                    NaN
# 12725       82919   68664     NaN                 NaN                    NaN
# 12726       82920   68664     NaN                 NaN                    NaN
#
#        HeavyMarketing  RuntimeMinutes        Title     IDImdb ReleaseDate  \
# 21490             NaN             729        Out 1  tt0246135  2015-11-18
# 29157             NaN             729        Out 1  tt0246135  2015-11-18
# 12724             NaN             632  Noce i dnie  tt0073460  1975-09-23
# 12725             NaN             632  Noce i dnie  tt0073460  1975-09-23
# 12726             NaN             632  Noce i dnie  tt0073460  1975-09-23
#
# ...

# %%
sin_largas = dummy_df[dummy_df.RuntimeMinutes<200]

# %%
sin_largas.head(1000)
# Out:
#       Unnamed: 0     ID_x  Budget  StudioInterference  PrePremiereScreenings  \
# 0              0    56132     NaN                 NaN                    NaN
# 1              1    68488     NaN                 NaN                    NaN
# 2              2    48663     NaN                 NaN                    NaN
# 3              3    51585     NaN                 NaN                    NaN
# 4              4    48180     NaN                 NaN                    NaN
# ...          ...      ...     ...                 ...                    ...
# 1001        1001  1038304     NaN                 NaN                    NaN
# 1002        1002    54295     NaN                 NaN                    NaN
# 1003        1003   932654     NaN                 NaN                    NaN
# 1004        1004    35491     NaN                 NaN                    NaN
# 1005        1005    30134     NaN                 NaN                    NaN
#
# ...

# %%
sin_larga_where  = dummy_df.where(dummy_df.RuntimeMinutes<200)

# %%
sin_larga_where.head(10000)
# Out:
#       Unnamed: 0      ID_x      Budget  StudioInterference  \
# 0            0.0   56132.0         NaN                 NaN
# 1            1.0   68488.0         NaN                 NaN
# 2            2.0   48663.0         NaN                 NaN
# 3            3.0   51585.0         NaN                 NaN
# 4            4.0   48180.0         NaN                 NaN
# ...          ...       ...         ...                 ...
# 9995      9995.0  103605.0  30000000.0                 NaN
# 9996      9996.0  103605.0  30000000.0                 NaN
# 9997      9997.0  103605.0  30000000.0                 NaN
# 9998      9998.0  103605.0  30000000.0                 NaN
# 9999      9999.0  103605.0  30000000.0                 NaN
#
#       PrePremiereScreenings  HeavyMarketing  RuntimeMinutes  \
# 0                       NaN             NaN            94.0
# 1                       NaN             NaN           100.0
# 2                       NaN             NaN            75.0
# ...

# %%
def agregar_texto(col_name):
    return "Pelicula: "+col_name

# %%
dummy_df['Title_2'] = dummy_df.Title.apply(agregar_texto)
# Out:
# /usr/local/lib/python3.6/dist-packages/dask/dataframe/core.py:3199: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=('Title', 'object'))
#
#   warnings.warn(meta_warning(meta))

# %%
dummy_df
# Out:
# Dask DataFrame Structure:
#                Unnamed: 0   ID_x   Budget StudioInterference PrePremiereScreenings HeavyMarketing RuntimeMinutes   Title  IDImdb ReleaseDate Description Keywords Certification Lanuguages Filming locations Technical specs IDTmdb IDDataLens IDCollection IDGenre IDMovie_x     id  Name_x     ID_y IDAwardType Category IDMovie_y IDMovie IDMoviePortal     Rate  Votes     ID  Name_y Homepage Title_2
# npartitions=39
#                     int64  int64  float64            float64               float64        float64          int64  object  object      object      object   object        object    float64           float64         float64  int64    float64      float64   int64     int64  int64  object  float64     float64   object   float64   int64         int64  float64  int64  int64  object   object  object
# ...
